# %%
#Dagney Cooke Homework

# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import sem

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
mouse_drug_data_to_load = "data/mouse_drug_data.csv"
clinical_trial_data_to_load = "data/clinicaltrial_data.csv"

# Read the Mouse and Drug Data and the Clinical Trial Data
mouse_data = pd.read_csv(mouse_drug_data_to_load)
trial_data = pd.read_csv(clinical_trial_data_to_load)

# Combine the data into a single dataset
all_data = pd.merge(mouse_data, trial_data, on="Mouse ID")
#drug_list = ["Capomulin","Infubinol","Ketapril","Placebo"]
#all_data = data_df[data_df["Drug"].isin(drug_list)] 


#Display the data table for preview
all_data.head()

#Your objective is to analyze the data to show how four treatments (Capomulin, Infubinol, Ketapril, and Placebo) compare.
# Out:
#   Mouse ID      Drug  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     f234  Stelasyn          0           45.000000                 0
# 1     f234  Stelasyn          5           47.313491                 0
# 2     f234  Stelasyn         10           47.904324                 0
# 3     f234  Stelasyn         15           48.735197                 1
# 4     f234  Stelasyn         20           51.112713                 2

# %% [markdown]
# ## Tumor Response to Treatment

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint 
grouped_means = all_data.groupby(["Drug","Timepoint"],as_index=False).mean()

# Convert to DataFrame
drug_timepoint = pd.DataFrame(grouped_means)

# Preview DataFrame
drug_timepoint = drug_timepoint.drop(columns=["Metastatic Sites"])
drug_timepoint.head()
# Out:
#         Drug  Timepoint  Tumor Volume (mm3)
# 0  Capomulin          0           45.000000
# 1  Capomulin          5           44.266086
# 2  Capomulin         10           43.084291
# 3  Capomulin         15           42.064317
# 4  Capomulin         20           40.716325

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint
tumor_vol_std = all_data.groupby(["Drug","Timepoint"],as_index=True).sem()

tumor_vol_column = tumor_vol_std["Tumor Volume (mm3)"].tolist()

drug_timepoint_stderror = drug_timepoint

drug_timepoint_stderror["Tumor Volume"] = tumor_vol_column
drug_timepoint_stderror = drug_timepoint_stderror.drop(columns=["Tumor Volume (mm3)"])
drug_timepoint_stderror = drug_timepoint_stderror.rename(columns={"Tumor Volume": "Tumor Volume (mm3)"})
# Preview DataFrame

drug_timepoint_stderror.head()
# Out:
#         Drug  Timepoint  Tumor Volume (mm3)
# 0  Capomulin          0            0.000000
# 1  Capomulin          5            0.448593
# 2  Capomulin         10            0.702684
# 3  Capomulin         15            0.838617
# 4  Capomulin         20            0.909731

# %%
# Minor Data Munging to Re-Format the Data Frames
drug_timepoint_rf = drug_timepoint.pivot(index="Timepoint", columns="Drug", values="Tumor Volume (mm3)")

# Preview that Reformatting worked
drug_timepoint_rf.head()
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# 5          47.248967  43.944859  47.527452  46.851818
# 10         49.101541  42.531957  49.463844  48.689881
# 15         51.067318  41.495061  51.529409  50.779059
# 20         53.346737  40.238325  54.067395  53.170334

# %%
drug_list = ["Capomulin","Infubinol","Ketapril","Placebo"]
drug_timepoint_trimmed = drug_timepoint[drug_timepoint["Drug"].isin(drug_list)] 
drug_timepoint_stderror_trimmed = drug_timepoint_stderror[drug_timepoint_stderror["Drug"].isin(drug_list)] 
# Generate the Plot (with Error Bars)
# Save the Figure
fig, ax = plt.subplots()
# for every set of 5 data points in means, use every 5 data points in stderror
x_axis = all_data["Timepoint"].unique()
x_axis = x_axis.tolist()

markers = ["o","^","s","D"]
colors = ["red","blue","green","black"]
labels = drug_timepoint_trimmed["Drug"].unique().tolist()
i = 0
count = 0
for i in range(0,len(drug_timepoint_trimmed["Tumor Volume (mm3)"]),10):
    ax.errorbar(x_axis,
                drug_timepoint_trimmed.iloc[i:i+10,2].tolist(),
                yerr=drug_timepoint_stderror_trimmed.iloc[i:i+10,2].tolist(),
                label=labels[count],
                fmt=markers[count],
                color = colors[count],
                linestyle="--",
                linewidth = .8,
                markersize = 5
                )
    count = count +1
plt.grid(axis='y')
plt.title("Tumor Response to Treatment")
plt.xlabel("Time (Days)")
plt.ylabel("Tumor Volume (mm3)")
plt.legend()
print(labels)
# Out:
# ['Capomulin', 'Infubinol', 'Ketapril', 'Placebo']

# %%
# Show the Figure
plt.show()

# %% [markdown]
# ![Tumor Response to Treatment](../Images/treatment.png)

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
# Store the Mean Met. Site Data Grouped by Drug and Timepoint 
grouped_means = all_data.groupby(["Drug","Timepoint"],as_index=True).mean()

# Convert to DataFrame
metastatic_means = pd.DataFrame(grouped_means)

# Preview DataFrame
metastatic_means = metastatic_means.drop(columns=["Tumor Volume (mm3)"])

# Preview DataFrame
metastatic_means.head()
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.160000
#           10                 0.320000
#           15                 0.375000
#           20                 0.652174

# %%
# Store the Standard Error associated with Met. Sites Grouped by Drug and Timepoint 
grouped_stderr = all_data.groupby(["Drug","Timepoint"],as_index=True).sem()
metastatic_stderr_list = grouped_stderr["Metastatic Sites"].tolist()

# Convert to DataFrame
metastatic_stderr = pd.DataFrame(grouped_stderr)
metastatic_stderr = metastatic_stderr.drop(columns=["Mouse ID","Tumor Volume (mm3)"])

metastatic_stderr.head()
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.074833
#           10                 0.125433
#           15                 0.132048
#           20                 0.161621

# %%
# Group means with as_index=False
grouped_means_rf = all_data.groupby(["Drug","Timepoint"],as_index=False).mean()

# Convert to DataFrame
metastatic_means_rf = pd.DataFrame(grouped_means_rf)

# Drop tumor volume column
metastatic_means_rf = metastatic_means_rf.drop(columns=["Tumor Volume (mm3)"])

# Minor Data Munging to Re-Format the Data Frames
metastatic_means_pivot = metastatic_means_rf.pivot(index="Timepoint", columns="Drug", values="Metastatic Sites")

# Preview that Reformatting worked
metastatic_means_pivot.head()
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.160000  0.380952   0.280000  0.304348  0.260870  0.375000
# 10          0.320000  0.600000   0.666667  0.590909  0.523810  0.833333
# 15          0.375000  0.789474   0.904762  0.842105  0.857143  1.250000
# 20          0.652174  1.111111   1.050000  1.210526  1.150000  1.526316
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# 5          0.320000  0.120000  0.240000   0.166667
# 10         0.565217  0.250000  0.478261   0.500000
# 15         0.764706  0.333333  0.782609   0.809524
# 20         1.000000  0.347826  0.952381   1.294118

# %%
drug_list = ["Capomulin","Infubinol","Ketapril","Placebo"]
metastatic_means_trimmed = metastatic_means_rf[metastatic_means_rf["Drug"].isin(drug_list)] 



metastatic_stderr_trimmed = grouped_means_rf[grouped_means_rf["Drug"].isin(drug_list)] 

# Generate the Plot (with Error Bars)
# Save the Figure
fig, ax = plt.subplots()
# for every set of 5 data points in means, use every 5 data points in stderror
x_axis = all_data["Timepoint"].unique()
x_axis = x_axis.tolist()

markers = ["o","^","s","D"]
colors = ["red","blue","green","black"]
labels = metastatic_means_trimmed["Drug"].unique().tolist()
i = 0
count = 0
for i in range(0,len(metastatic_means_trimmed["Metastatic Sites"]),10):
    ax.errorbar(x_axis,
                metastatic_means_trimmed.iloc[i:i+10,2].tolist(),
                yerr=metastatic_stderr_trimmed.iloc[i:i+10,2].tolist(),
                label=labels[count],
                fmt=markers[count],
                color = colors[count],
                linestyle="--",
                linewidth = .8,
                markersize = 5
                )
    count = count +1
plt.legend()
plt.ylim(0,4)
plt.grid(b=None)
plt.title("Metastatic Spread During Treatment")
plt.xlabel("Treatment Duration (Days)")
plt.ylabel("Met. Sites")
#plt.grid(axis="y")
# Out:
# Text(0, 0.5, 'Met. Sites')

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/spread.png)

# %% [markdown]
# ## Survival Rates

# %%
# Store the Count of Mice Grouped by Drug and Timepoint (W can pass any metric)

# Convert to DataFrame

# Preview DataFrame

# %%
# Minor Data Munging to Re-Format the Data Frames

# Preview the Data Frame

# %%
# Generate the Plot (Accounting for percentages)

# Save the Figure

# Show the Figure
plt.show()

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/survival.png)

# %% [markdown]
# ## Summary Bar Graph

# %%
# Calculate the percent changes for each drug

# Display the data to confirm

# %%
# Store all Relevant Percent Changes into a Tuple


# Splice the data between passing and failing drugs


# Orient widths. Add labels, tick marks, etc. 


# Use functions to label the percentages of changes


# Call functions to implement the function calls


# Save the Figure


# Show the Figure
fig.show()

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/change.png)
